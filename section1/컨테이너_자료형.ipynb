# %% [markdown]
# ## 컨테이너 자료형(list, dict)
#
# ### list
# - [자료1, 자료2]
#
# #### 선언(create)

# %%
names = ["jenny", "james", "john"]
names
# Out:
# ['jenny', 'james', 'john']

# %% [markdown]
# #### 인덱싱과 슬라이싱(read)
#
# 문자 자료형과 마찬가지로 주어진 리스트에서 필요한 부분만 가져올 수 있음
# 대괄호 [시작:끝:단위]를 사용

# %%
names[1]
# Out:
# 'james'

# %% [markdown]
# #### 수정(update)

# %%
names[0] = "tom"
names
# Out:
# ['tom', 'james', 'john']

# %%
names.append("jammy")
names
# Out:
# ['james', 'john', 'jammy']

# %% [markdown]
# #### 삭제(delete)

# %%
names.remove("tom")
names
# Out:
# ['james', 'john']

# %% [markdown]
# ### dict
#
# - {key: val, key: val}
#
# #### 선언(create)

# %%
users = {"aa123": "123", "bb456": "456", "cc678": "678"}
users
# Out:
# {'aa123': '123', 'bb456': '456', 'cc678': '678'}

# %% [markdown]
# #### 조회(read)
#
# 인덱스가 없음. 이를 hash형 자료라고도 하는데
# 훨씬 더 검색 속도가 빠름
# [key] 값으로 조회

# %%
users["aa123"]
# Out:
# '123'

# %% [markdown]
# #### 수정(update)

# %%
users["aa123"] = "qq123"
users
# Out:
# {'aa123': 'qq123', 'bb456': '456', 'cc678': '678'}

# %%
# 새로운 요소를 추가하는 방법도 같음
users["dd123"] = "test"
users
# Out:
# {'aa123': 'qq123', 'bb456': '456', 'cc678': '678', 'dd123': 'test'}

# %% [markdown]
# #### 삭제(delete)

# %%
del users["aa123"]
users
# Out:
# {'bb456': '456', 'cc678': '678', 'dd123': 'test'}
