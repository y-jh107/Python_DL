# %% [markdown]
# ## 기본 자료형(숫자, 문자, 참거짓)
#
# #### 숫자
# - 정수(int)
# - 실수(float)

# %%
print(1)
print(1.5)
# Out:
# 1
# 1.5

# %% [markdown]
# #### type 함수

# %%
type(1)
# Out:
# int

# %%
type(1.5)
# Out:
# float

# %% [markdown]
# 사칙연산
# - +: 더하기
# - -: 빼기
# - *: 곱하기
# - /: 나누기
# - //: 몫
# - %: 나머지

# %%
10 % 3
# Out:
# 1

# %% [markdown]
# #### 문자
#
# - 문자(str)
# - 작은 따옴표 또는 큰 따옴표로 처음과 끝을 표시하여 선언

# %%
print("안녕")
# Out:
# 안녕

# %%
type("안녕")
# Out:
# str

# %% [markdown]
# #### 문자의 인덱싱, 슬라이싱
#
# 주어진 문자에서 필요한 부분만 가져올 수 있음
# 대괄호 [시작:끝:단위] 를 사용

# %%
"동해물과 백두산이 마르고 닳도록"[0:4:2]
# Out:
# '동물'

# %% [markdown]
# #### 참&거짓
#
# - 불린(bool)
# - True, False

# %%
True
# Out:
# True

# %% [markdown]
# 불(bool) 데이터는 주료 비교 연산, 논리 연산의 결과로 추후 조건문, 반복문 등 프로그래밍을 할 때 자주 사용하게 됨
#
# #### 비교 연산
#
# - ==: 같은가?
# - !=: 다른가?
# - \>=: 크거나 같은가?(작거나 같은가?)
# - \>: 큰가?(작은가?)

# %%
10 == 1
# Out:
# False

# %% [markdown]
# #### 논리 연산
#
# - and
# - or
# - not

# %%
True or False
# Out:
# True

# %%
not False
# Out:
# True

# %% [markdown]
# ## 변수
#
# #### 변수
#
# - 데이터를 담는 공간
# - 위에서 살펴본 자료형을 저장할 수 있음
#
# #### 선언방법
#
# - 변수명 = 데이터

# %%
# 변수명 = 데이터
fruit1 = "사과"
fruit2 = "망고"

print(f"첫번째 과일은 {fruit1}, 두번째 과일은 {fruit2}")
# Out:
# 첫번째 과일은 사과, 두번째 과일은 망고
